# %% [raw]
# 1. Why are functions advantageous to have in your programs?
#
# Answer:
#
# Functions will reduce the effort of writing the same piece of code again and again, just create a function with the code and call it when every you need it. They are easy to maintain and update.

# %% [raw]
# 2. When does the code in a function run: when it's specified or when it's called?
#
# Answer:
#
# function will run only when it's called not at the delaration time.

# %% [raw]
# 3. What statement creates a function?
#
# Answer:
#
# def statement is used to create a function.
# eg: def addition(a,b):
#         return (a +b)

# %% [raw]
# 4. What is the difference between a function and a function call?
#
# Answer:
#
# Function is a set of statements encloed in wrapper using def statement.
# Function call will execute the statements written inside the function and returns a value.

# %% [raw]
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Answer:
#
# Only one global and one local scopes in python.

# %% [raw]
# 6. What happens to variables in a local scope when the function call returns?
#
# Answer:
#
# After function call returns back the local variables will be removed from logical memory.

# %% [raw]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Answer:
#
# Return value is the value generated by the evaluation of an expression/function. Yes,we can use return value in an expression.

# %% [raw]
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Answer:
#
# if there is not return statment then the function will not return anything.

# %% [raw]
# 9. How do you make a function variable refer to the global variable?
#
# Answer:
#
# we need to delare the varialbe using a global stament.
# eg: global X

# %% [raw]
# 10. What is the data type of None?
#
# Answer: NoneType is the datetype of None. see the below example:

# %%
X = None
type(X)
# Out:
# NoneType

# %% [raw]
# 11. What does the sentence import areallyourpetsnamederic do?
#
# Answer:
#
# it imports all the modules inside the areallyourpetsnamederic.

# %% [raw]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Answer:
#
# Yes we can call bcon() after importing spam like the following way:
# import spam
# spam.bacon()

# %% [raw]
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Answer:
#
# Use the try clause to prevent the program from crshing.

# %% [raw]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Answer:
#
# try clause is used to put the code in side of it where we are expecting some error.
# except caluse is used to handle the error generated from try clause.
